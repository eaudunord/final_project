# %%
import sqlite3
import pandas as pd
import numpy as np
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers.experimental import preprocessing

# %%
region_dict = {
    101:'Northeast Climate Region',
    102:'Upper Midwest Climate Region',
    103:'Ohio Valley Climate Region',
    104:'Southeast Climate Region',
    105:'Northern Rockies and Plains Climate Region',
    106:'South Climate Region',
    107:'Southwest Climate Region',
    108:'Northwest Climate Region',
    109:'West Climate Region'
}

# %%
# Create a SQL connection to our SQLite database
con = sqlite3.connect("../FPA_FOD_20210617.sqlite")

cur = con.cursor()

# %%
cur.execute('SELECT region_id, DISCOVERY_DATE, FPA_ID FROM Fires limit 10')
cur.fetchall()
# Out:
# [(109, '2/2/2005 0:00', 'FS-1418826'),
#  (109, '5/12/2004 0:00', 'FS-1418827'),
#  (109, '5/31/2004 0:00', 'FS-1418835'),
#  (109, '6/28/2004 0:00', 'FS-1418845'),
#  (109, '6/28/2004 0:00', 'FS-1418847'),
#  (109, '6/30/2004 0:00', 'FS-1418849'),
#  (109, '7/1/2004 0:00', 'FS-1418851'),
#  (109, '3/8/2005 0:00', 'FS-1418854'),
#  (109, '3/15/2005 0:00', 'FS-1418856'),
#  (109, '7/1/2004 0:00', 'FS-1418859')]

# %%
df = pd.read_sql_query("SELECT region_id, DISCOVERY_DATE FROM Fires", con).dropna()

# %%
df.head(10)
# Out:
#    region_id  DISCOVERY_DATE
# 0      109.0   2/2/2005 0:00
# 1      109.0  5/12/2004 0:00
# 2      109.0  5/31/2004 0:00
# 3      109.0  6/28/2004 0:00
# 4      109.0  6/28/2004 0:00
# 5      109.0  6/30/2004 0:00
# 6      109.0   7/1/2004 0:00
# 7      109.0   3/8/2005 0:00
# 8      109.0  3/15/2005 0:00
# 9      109.0   7/1/2004 0:00

# %%
df['DISCOVERY_DATE'] = pd.to_datetime(df['DISCOVERY_DATE'])
df.head()
# Out:
#    region_id DISCOVERY_DATE
# 0      109.0     2005-02-02
# 1      109.0     2004-05-12
# 2      109.0     2004-05-31
# 3      109.0     2004-06-28
# 4      109.0     2004-06-28

# %%
per = df.DISCOVERY_DATE.dt.to_period("M")
fires_refactor = df.groupby([per,'region_id']).count()
fires_refactor.head()
# Out:
#                           DISCOVERY_DATE
# DISCOVERY_DATE region_id
# 1992-01        101.0                  86
#                102.0                   4
#                103.0                 119
#                104.0                2609
#                105.0                  86

# %%
fires_refactor.rename(columns={'DISCOVERY_DATE':'count'},inplace=True)
fires_refactor = fires_refactor.reset_index()
fires_refactor.head()
# Out:
#   DISCOVERY_DATE  region_id  count
# 0        1992-01      101.0     86
# 1        1992-01      102.0      4
# 2        1992-01      103.0    119
# 3        1992-01      104.0   2609
# 4        1992-01      105.0     86

# %%
fires_refactor['month'] = fires_refactor.iloc[:,0].dt.strftime('%m')
fires_refactor.rename(columns={'DISCOVERY_DATE':'date'},inplace=True)
fires_refactor.head()
# Out:
#       date  region_id  count month
# 0  1992-01      101.0     86    01
# 1  1992-01      102.0      4    01
# 2  1992-01      103.0    119    01
# 3  1992-01      104.0   2609    01
# 4  1992-01      105.0     86    01

# %%
weather = pd.read_sql_query('select date, region_id, departure_avg_temp, departure_precipitation, departure_max_temp, departure_min_temp from weather',con).dropna()
weather['date'] = pd.to_datetime(weather['date']).dt.to_period("M")
weather.shape
# Out:
# (2817, 6)

# %%
data = weather.merge(fires_refactor,how="left",on=["date","region_id"]).fillna(0)
data.shape
# Out:
# (2817, 8)

# %%
data.head(20)
# Out:
#        date  region_id  departure_avg_temp  departure_precipitation  \
# 0   1992-01        101                 2.2                    -0.68
# 1   1992-02        101                 3.2                    -0.50
# 2   1992-03        101                -2.3                     0.29
# 3   1992-04        101                -0.9                    -0.76
# 4   1992-05        101                -0.6                    -0.89
# 5   1992-06        101                -1.6                    -0.46
# 6   1992-07        101                -2.7                     1.68
# 7   1992-08        101                -1.7                     0.32
# 8   1992-09        101                -0.2                     0.14
# 9   1992-10        101                -3.3                    -0.74
# 10  1992-11        101                 0.0                     0.80
# 11  1992-12        101                 2.3                     0.03
# 12  1993-01        101                 4.1                    -0.47
# 13  1993-02        101                -5.0                     0.00
# 14  1993-03        101                -2.5                     1.30
# 15  1993-04        101                 1.2                     2.01
# 16  1993-05        101                 1.2                    -1.80
# 17  1993-06        101                -0.2                    -0.20
# 18  1993-07        101                 1.4                    -1.18
# 19  1993-08        101                 2.1                    -0.86
#
#     departure_max_temp  departure_min_temp  count month
# 0                  2.0                 2.4   86.0    01
# 1                  2.4                 3.9  130.0    02
# 2                 -2.5                -2.2  283.0    03
# 3                 -1.6                -0.2  743.0    04
# 4                  0.3                -1.5  830.0    05
# 5                 -1.8                -1.6  227.0    06
# 6                 -4.0                -1.4   96.0    07
# 7                 -2.7                -0.8   53.0    08
# 8                 -0.7                 0.2   49.0    09
# 9                 -3.9                -2.8   79.0    10
# 10                -1.3                 1.2   37.0    11
# 11                 1.7                 3.1   36.0    12
# 12                 3.1                 5.1   33.0    01
# 13                -4.0                -6.1   51.0    02
# 14                -2.2                -2.9   10.0    03
# 15                 1.1                 1.2  354.0    04
# 16                 1.7                 0.7  501.0    05
# 17                -0.1                -0.5  116.0    06
# 18                 1.3                 1.4  479.0    07
# 19                 2.3                 1.8  290.0    08

# %%
def build_and_compile_model(norm):
  model = keras.Sequential([
      norm,
      layers.Dense(64, activation='relu'),
      layers.Dense(64, activation='relu'),
      layers.Dense(1)
  ])

  model.compile(loss='mean_absolute_error',
                optimizer=tf.keras.optimizers.Adam(0.001))
  return model

# %%
data = data.astype({'region_id':float,'count':float,'month':float})
data.dtypes
# Out:
# date                       period[M]
# region_id                    float64
# departure_avg_temp           float64
# departure_precipitation      float64
# departure_max_temp           float64
# departure_min_temp           float64
# count                        float64
# month                        float64
# dtype: object

# %%
train_features = data.iloc[:,1:8].sample(frac=0.8, random_state=0)
test_features = data.iloc[:,1:8].drop(train_features.index)

train_labels = train_features.pop('count')
test_labels = test_features.pop('count')
train_features.head()
# Out:
#       region_id  departure_avg_temp  departure_precipitation  \
# 1726      106.0                 0.8                    -0.82
# 333       102.0                -5.2                    -0.15
# 70        101.0                -1.5                     1.57
# 569       102.0                 0.2                     1.96
# 118       101.0                 6.0                    -1.52
#
#       departure_max_temp  departure_min_temp  month
# 1726                 1.0                 0.6    6.0
# 333                 -6.5                -4.0    9.0
# 70                  -2.6                -0.5   11.0
# 569                 -0.6                 1.0    5.0
# 118                  7.5                 4.5   11.0

# %%
normalizer = preprocessing.Normalization(axis=-1)
normalizer.adapt(np.array(train_features))

# %%
dnn_model = build_and_compile_model(normalizer)
dnn_model.summary()
# Out:
# Model: "sequential_21"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# normalization_19 (Normalizat (None, 6)                 13
# _________________________________________________________________
# dense_63 (Dense)             (None, 64)                448
# _________________________________________________________________
# dense_64 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_65 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 4,686
# Trainable params: 4,673
# Non-trainable params: 13
# _________________________________________________________________

# %%
# %%time
history = dnn_model.fit(
    train_features, train_labels,
    validation_split=0.2,
    verbose=0, epochs=1500)
# Out:
# Wall time: 1min 54s

# %%
test_predictions = dnn_model.predict(test_features).flatten()

# %%
plt.axes(aspect='equal')
plt.scatter(test_labels, test_predictions)
plt.xlabel('True Values [Fire Count]')
plt.ylabel('Predictions [Fire Count]')

lims = [0, 3000]
plt.xlim(lims)
plt.ylim(lims)
mpl.style.use('seaborn')
plt.title('Continental US Predicted vs Actual')
_ = plt.plot(lims, lims, 'C2')

# %%
# dnn_model.get_weights()

# %%
# break out into separate models by region
NE_train_features = data[data['region_id'] == 101].iloc[:,2:8].sample(frac=0.8, random_state=1)
NE_test_features = data[data['region_id'] == 101].iloc[:,2:8].drop(NE_train_features.index)

NE_train_labels = NE_train_features.pop('count')
NE_test_labels = NE_test_features.pop('count')
NE_train_features.head()
# Out:
#      departure_avg_temp  departure_precipitation  departure_max_temp  \
# 80                  2.5                    -1.11                 2.8
# 268                 1.7                     1.00                 1.0
# 310                 0.2                    -0.94                 0.9
# 187                 1.7                    -0.03                 1.8
# 105                 0.8                    -1.04                 1.1
#
#      departure_min_temp  month
# 80                  2.2    9.0
# 268                 2.4    5.0
# 310                -0.6   11.0
# 187                 1.6    8.0
# 105                 0.5   10.0

# %%
normalizer = preprocessing.Normalization(axis=-1)
normalizer.adapt(np.array(NE_train_features))

# %%
dnn_model = build_and_compile_model(normalizer)

# %%
# %%time
history = dnn_model.fit(
    NE_train_features, NE_train_labels,
    validation_data=(NE_test_features, NE_test_labels),
    verbose=0, epochs=2500)
# Out:
# Wall time: 57 s

# %%
NE_test_predictions = dnn_model.predict(NE_test_features).flatten()

# %%
plt.axes(aspect='equal')
plt.scatter(NE_test_labels, NE_test_predictions)
plt.xlabel('True Values [Fire Count]')
plt.ylabel('Predictions [Fire Count]')

lims = [0, 3000]
plt.xlim(lims)
plt.ylim(lims)
mpl.style.use('seaborn')
_ = plt.plot(lims, lims, 'C2')

# %%
# evaluate the model
train_acc = dnn_model.evaluate(NE_train_features, NE_train_labels, verbose=0)
test_acc = dnn_model.evaluate(NE_test_features, NE_test_labels, verbose=0)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# Out:
# Train: 248.524, Test: 226.591

# %%
# learning curves of model accuracy
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.grid(True)
plt.xlabel('Epochs')
plt.ylabel('Error [Fire Count]')
mpl.style.use('seaborn')
plt.show()

# %%
NE_data = data[data['region_id']==101]
NE_data['count'] = NE_data['count'].shift(-1)
NE_data.dropna(inplace=True)
NE_data.tail()
# Out:
# <ipython-input-220-bbfda4417774>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NE_data['count'] = NE_data['count'].shift(-1)
# <ipython-input-220-bbfda4417774>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NE_data.dropna(inplace=True)
#         date  region_id  departure_avg_temp  departure_precipitation  \
# 307  2017-08      101.0                -0.3                    -0.27
# 308  2017-09      101.0                 3.7                    -1.17
# 309  2017-10      101.0                 6.7                     2.43
# 310  2017-11      101.0                 0.2                    -0.94
# 311  2017-12      101.0                -1.5                    -0.83
#
#      departure_max_temp  departure_min_temp  count  month
# 307                -0.5                -0.1  432.0    8.0
# 308                 3.6                 3.8  625.0    9.0
# 309                 6.9                 6.6  375.0   10.0
# 310                 0.9                -0.6  182.0   11.0
# 311                -1.9                -1.0   89.0   12.0

# %%
# run model on shifted data. Could be useful for predicting fire risk for coming month.
NE_train_features = NE_data[NE_data['region_id'] == 101].iloc[:,2:8].sample(frac=0.8, random_state=1)
NE_test_features = NE_data[NE_data['region_id'] == 101].iloc[:,2:8].drop(NE_train_features.index)

NE_train_labels = NE_train_features.pop('count')
NE_test_labels = NE_test_features.pop('count')
NE_train_features.head()
# Out:
#      departure_avg_temp  departure_precipitation  departure_max_temp  \
# 80                  2.5                    -1.11                 2.8
# 267                 0.8                     0.24                 1.7
# 309                 6.7                     2.43                 6.9
# 187                 1.7                    -0.03                 1.8
# 105                 0.8                    -1.04                 1.1
#
#      departure_min_temp  month
# 80                  2.2    9.0
# 267                -0.2    4.0
# 309                 6.6   10.0
# 187                 1.6    8.0
# 105                 0.5   10.0

# %%
normalizer = preprocessing.Normalization(axis=-1)
normalizer.adapt(np.array(NE_train_features))

# %%
dnn_model = build_and_compile_model(normalizer)

# %%
# %%time
history = dnn_model.fit(
    NE_train_features, NE_train_labels,
    validation_data=(NE_test_features, NE_test_labels),
    verbose=0, epochs=2500)
# Out:
# Wall time: 60 s

# %%
NE_test_predictions = dnn_model.predict(NE_test_features).flatten()

# %%
plt.axes(aspect='equal')
plt.scatter(NE_test_labels, NE_test_predictions)
plt.xlabel('True Values [Fire Count]')
plt.ylabel('Predictions [Fire Count]')

lims = [0, 3000]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)

# %%
# evaluate the model
train_acc = dnn_model.evaluate(NE_train_features, NE_train_labels, verbose=0)
test_acc = dnn_model.evaluate(NE_test_features, NE_test_labels, verbose=0)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# learning curves of model accuracy
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()
# Out:
# Train: 287.437, Test: 275.477

# %%
# iterate through rest of regions
for i in range(101,110):
#     reg_data = data[data['region_id']== i]
#     reg_data['count'] = reg_data['count'].shift(-1)
#     reg_data.dropna(inplace=True)
    train_features = data[data['region_id'] == i].iloc[:,2:8].sample(frac=0.8, random_state=1)
    test_features = data[data['region_id'] == i].iloc[:,2:8].drop(train_features.index)

    train_features = reg_data.iloc[:,2:8].sample(frac=0.8, random_state=1)
    test_features = reg_data.iloc[:,2:8].drop(train_features.index)

    train_labels = train_features.pop('count')
    test_labels = test_features.pop('count')
    
    normalizer = preprocessing.Normalization(axis=-1)
    normalizer.adapt(np.array(train_features))
    
    dnn_model = build_and_compile_model(normalizer)
    history = dnn_model.fit(
    train_features, train_labels,
    validation_data=(test_features, test_labels),
    verbose=0, epochs=2500)
    
    test_predictions = dnn_model.predict(test_features).flatten()
    plt.axes(aspect='equal')
    plt.scatter(test_labels, test_predictions)
    plt.xlabel('True Values [Fire Count]')
    plt.ylabel('Predictions [Fire Count]')
    plt.title(region_dict[i])

    lims = [0, 3000]
    plt.xlim(lims)
    plt.ylim(lims)
    plt.grid(True)
    mpl.style.use('seaborn')
    _ = plt.plot(lims, lims, 'C2')
    plt.savefig(f"figures/predictions {region_dict[i]}.png")
    plt.show()
    
    plt.plot(history.history['loss'], label='train')
    plt.plot(history.history['val_loss'], label='test')
    plt.legend()
    plt.title(region_dict[i]+" Model Accuracy")
    plt.grid(True)
    plt.xlabel('Epochs')
    plt.ylabel('Error [Fire Count]')
    mpl.style.use('seaborn')
    plt.savefig(f"figures/accuracy {region_dict[i]}.png" )
    plt.show()

# %%
con.close()
